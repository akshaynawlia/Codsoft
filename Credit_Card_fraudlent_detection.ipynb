# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
main_data = pd.read_csv('creditcard.csv')

# %%
main_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Data preProcessing

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15936 entries, 0 to 15935
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    15936 non-null  int64
#  1   V1      15936 non-null  float64
#  2   V2      15936 non-null  float64
#  3   V3      15936 non-null  float64
#  4   V4      15936 non-null  float64
#  5   V5      15936 non-null  float64
#  6   V6      15936 non-null  float64
#  7   V7      15936 non-null  float64
#  8   V8      15936 non-null  float64
#  9   V9      15936 non-null  float64
#  10  V10     15936 non-null  float64
#  11  V11     15936 non-null  float64
#  12  V12     15936 non-null  float64
#  13  V13     15936 non-null  float64
#  14  V14     15936 non-null  float64
#  15  V15     15936 non-null  float64
#  16  V16     15936 non-null  float64
#  17  V17     15936 non-null  float64
#  18  V18     15936 non-null  float64
#  19  V19     15936 non-null  float64
#  20  V20     15936 non-null  float64
#  21  V21     15936 non-null  float64
#  22  V22     15936 non-null  float64
#  23  V23     15935 non-null  float64
#  24  V24     15935 non-null  float64
#  25  V25     15935 non-null  float64
#  26  V26     15935 non-null  float64
#  27  V27     15935 non-null  float64
#  28  V28     15935 non-null  float64
#  29  Amount  15935 non-null  float64
#  30  Class   15935 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 3.8 MB

# %%
main_data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
main_data=main_data.dropna()

# %%
main_data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df = main_data

# %%
df.drop('Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 30 columns]

# %%
X  = df.drop('Class',axis=1)
Y = df['Class']
X.shape,Y.shape
# Out:
# ((15935, 29), (15935,))

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    15862
# 1.0       73
# Name: count, dtype: int64

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]
print(legit.shape)
print(fraud.shape)
# Out:
# (15862, 30)
# (73, 30)

# %%
legit.Amount.describe()
# Out:
# count    15862.000000
# mean        66.280151
# std        188.898885
# min          0.000000
# 25%          5.522500
# 50%         15.950000
# 75%         53.890000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      73.000000
# mean       90.307123
# std       271.634360
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#              V1       V2         V3        V4        V5        V6        V7  \
# Class
# 0.0   -0.219072  0.25000   0.862854  0.272641 -0.105868  0.124522 -0.112681
# 1.0   -7.929807  6.19312 -11.997831  6.555050 -5.474984 -2.480356 -8.354317
#
#              V8        V9       V10  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.016178  0.879120 -0.254407  ...  0.028173 -0.064056 -0.161585
# 1.0    3.668478 -3.086988 -7.573464  ...  0.671905  0.441100 -0.295856
#
#             V23       V24       V25       V26       V27       V28     Amount
# Class
# 0.0   -0.035040  0.013076  0.117023  0.037111  0.011206  0.005907  66.280151
# 1.0   -0.358994 -0.328925  0.216076  0.209323  0.927187  0.061380  90.307123
#
# [2 rows x 29 columns]

# %%
legit_sample  = legit.sample(n=73)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)

# %%
new_df.head()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 690   -0.608941  0.961271  0.978330 -0.375420  0.955270 -0.111386  1.145462
# 10873  0.902440 -0.492683  0.871188  1.835026 -0.386624  1.154144 -0.506433
# 930   -0.590526  0.756030  1.620537 -0.109645  0.062481 -0.310831  0.386568
# 15556  1.220203  0.626811 -0.348619  1.116567  0.267166 -0.679456  0.203523
# 9100  -0.917521  0.410754  3.652738  1.620354 -1.124754  1.219126 -0.757576
#
#              V8        V9       V10  ...       V21       V22       V23  \
# 690   -0.070023 -0.523790 -0.775379  ...  0.034309 -0.010383 -0.425615
# 10873  0.246746  2.640259 -0.831725  ... -0.550729 -1.157186 -0.112098
# 930    0.279559 -0.491829 -0.146351  ... -0.138553 -0.430450  0.059278
# 15556 -0.090053 -0.355413 -0.403531  ... -0.019064 -0.006796 -0.175132
# 9100   0.576610  2.526952 -1.061938  ...  0.004541  0.865637 -0.284418
#
#             V24       V25       V26       V27       V28  Amount  Class
# 690   -1.022448  0.613098 -0.401181  0.051356  0.083632   39.05    0.0
# 10873 -0.837442  0.455233 -0.507548  0.037576  0.034385  134.31    0.0
# 930    0.172907 -0.357478  0.074625  0.266242  0.109266    4.99    0.0
# 15556 -0.098718  0.713283 -0.325487  0.029230  0.038269    1.00    0.0
# 9100   0.408572  0.343649  0.007354  0.405394  0.152524   28.07    0.0
#
# [5 rows x 30 columns]

# %%
new_df.tail()
# Out:
#               V1         V2         V3        V4         V5        V6  \
# 15566 -23.237920  13.487386 -25.188773  6.261733 -17.345188 -4.534989
# 15736 -23.914101  13.765942 -25.733734  6.290918 -17.784824 -4.572498
# 15751 -24.590245  14.044567 -26.278701  6.320089 -18.224513 -4.609968
# 15781 -25.266355  14.323254 -26.823673  6.349248 -18.664251 -4.647403
# 15810 -25.942434  14.601998 -27.368650  6.378395 -19.104033 -4.684806
#
#               V7         V8        V9       V10  ...       V21       V22  \
# 15566 -17.100492  15.374630 -3.845567 -8.511767  ...  1.769708 -1.691973
# 15736 -17.390764  15.794136 -3.819832 -8.442262  ...  1.773399 -1.748426
# 15751 -17.681003  16.213627 -3.794093 -8.372753  ...  1.777063 -1.804874
# 15781 -17.971212  16.633103 -3.768351 -8.303239  ...  1.780701 -1.861318
# 15810 -18.261393  17.052566 -3.742605 -8.233721  ...  1.784316 -1.917759
#
#             V23       V24       V25       V26       V27       V28  Amount  \
# 15566 -1.045673  0.143386  1.611577 -0.221576  1.481233  0.438125   99.99
# 15736 -1.093104  0.147807  1.663792 -0.221024  1.458076  0.430315   99.99
# 15751 -1.140605  0.152234  1.715997 -0.220471  1.434951  0.422492   99.99
# 15781 -1.188167  0.156667  1.768192 -0.219916  1.411855  0.414656   99.99
# 15810 -1.235787  0.161105  1.820378 -0.219359  1.388786  0.406810   99.99
#
#        Class
# 15566    1.0
# 15736    1.0
# 15751    1.0
# 15781    1.0
# 15810    1.0
#
# [5 rows x 30 columns]

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0.0    73
# 1.0    73
# Name: count, dtype: int64

# %%
X  = new_df.drop('Class',axis=1)
Y = new_df['Class']
X.shape,Y.shape
# Out:
# ((146, 29), (146,))

# %%
print(X)
print(Y)
# Out:
#               V1         V2         V3        V4         V5        V6  \
# 690    -0.608941   0.961271   0.978330 -0.375420   0.955270 -0.111386
# 10873   0.902440  -0.492683   0.871188  1.835026  -0.386624  1.154144
# 930    -0.590526   0.756030   1.620537 -0.109645   0.062481 -0.310831
# 15556   1.220203   0.626811  -0.348619  1.116567   0.267166 -0.679456
# 9100   -0.917521   0.410754   3.652738  1.620354  -1.124754  1.219126
# ...          ...        ...        ...       ...        ...       ...
# 15566 -23.237920  13.487386 -25.188773  6.261733 -17.345188 -4.534989
# 15736 -23.914101  13.765942 -25.733734  6.290918 -17.784824 -4.572498
# 15751 -24.590245  14.044567 -26.278701  6.320089 -18.224513 -4.609968
# 15781 -25.266355  14.323254 -26.823673  6.349248 -18.664251 -4.647403
# 15810 -25.942434  14.601998 -27.368650  6.378395 -19.104033 -4.684806
#
#               V7         V8        V9       V10  ...       V20       V21  \
# 690     1.145462  -0.070023 -0.523790 -0.775379  ... -0.045865  0.034309
# 10873  -0.506433   0.246746  2.640259 -0.831725  ...  0.000481 -0.550729
# 930     0.386568   0.279559 -0.491829 -0.146351  ...  0.028391 -0.138553
# 15556   0.203523  -0.090053 -0.355413 -0.403531  ... -0.068351 -0.019064
# 9100   -0.757576   0.576610  2.526952 -1.061938  ...  0.122905  0.004541
# ...          ...        ...       ...       ...  ...       ...       ...
# 15566 -17.100492  15.374630 -3.845567 -8.511767  ...  1.630787  1.769708
# 15736 -17.390764  15.794136 -3.819832 -8.442262  ...  1.640037  1.773399
# 15751 -17.681003  16.213627 -3.794093 -8.372753  ...  1.649202  1.777063
# 15781 -17.971212  16.633103 -3.768351 -8.303239  ...  1.658289  1.780701
# 15810 -18.261393  17.052566 -3.742605 -8.233721  ...  1.667304  1.784316
#
#             V22       V23       V24       V25       V26       V27       V28  \
# 690   -0.010383 -0.425615 -1.022448  0.613098 -0.401181  0.051356  0.083632
# 10873 -1.157186 -0.112098 -0.837442  0.455233 -0.507548  0.037576  0.034385
# 930   -0.430450  0.059278  0.172907 -0.357478  0.074625  0.266242  0.109266
# 15556 -0.006796 -0.175132 -0.098718  0.713283 -0.325487  0.029230  0.038269
# 9100   0.865637 -0.284418  0.408572  0.343649  0.007354  0.405394  0.152524
# ...         ...       ...       ...       ...       ...       ...       ...
# 15566 -1.691973 -1.045673  0.143386  1.611577 -0.221576  1.481233  0.438125
# 15736 -1.748426 -1.093104  0.147807  1.663792 -0.221024  1.458076  0.430315
# 15751 -1.804874 -1.140605  0.152234  1.715997 -0.220471  1.434951  0.422492
# 15781 -1.861318 -1.188167  0.156667  1.768192 -0.219916  1.411855  0.414656
# 15810 -1.917759 -1.235787  0.161105  1.820378 -0.219359  1.388786  0.406810
#
#        Amount
# 690     39.05
# 10873  134.31
# 930      4.99
# 15556    1.00
# 9100    28.07
# ...       ...
# 15566   99.99
# 15736   99.99
# 15751   99.99
# 15781   99.99
# 15810   99.99
#
# [146 rows x 29 columns]
# 690      0.0
# 10873    0.0
# 930      0.0
# 15556    0.0
# 9100     0.0
#         ...
# 15566    1.0
# 15736    1.0
# 15751    1.0
# 15781    1.0
# 15810    1.0
# Name: Class, Length: 146, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (116, 29)
# (30, 29)
# (116,)
# (30,)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data : ',training_data_accuracy)
# Out:
# Accuracy on training data :  0.9913793103448276

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test data : ',test_data_accuracy)
# Out:
# Accuracy on test data :  1.0
